# %% [markdown]
# # FIFA2019

# %% [markdown]
# ## 用 Python CSV 套件，處理資料

# %%
fifa_source = './data/lite_fifa19.csv'

# %%
# %%time 

import datetime

import  csv

fifa_source = './data/lite_fifa19.csv'

# file handle 

with open(fifa_source, 'r', newline='') as f:
    rows = csv.reader(f, delimiter=',')
    # rows is a iterable , next() and for..looping
    
    header = next(rows)
    lines = []
    for each_row in rows:
        lines.append(each_row)

print('done')
# Out:
# done
# CPU times: user 110 ms, sys: 22.2 ms, total: 132 ms
# Wall time: 138 ms

# %%
len(header), len(lines), len(lines[0])
# Out:
# (31, 18207, 31)

# %%
# %%time

def create_dict_from_line(hd, line):
    output = {}
    for k, v in zip(hd, line):
        output[k] = v
    return output

fifa = [create_dict_from_line(header, line) for line in lines]
# Out:
# CPU times: user 62.2 ms, sys: 14.3 ms, total: 76.5 ms
# Wall time: 78.2 ms

# %%
fifa[0]
# Out:
# {'Name': 'L. Messi',
#  'Age': '31',
#  'Nationality': 'Argentina',
#  'Overall': '94',
#  'Potential': '94',
#  'Club': 'FC Barcelona',
#  'Value': '110.5',
#  'Wage': '565.0',
#  'Height': "5'7",
#  'Weight': '159lbs',
#  'Special': '2202',
#  'Preferred Foot': 'Left',
#  'Weak Foot': '4.0',
#  'Acceleration': '91.0',
#  'SprintSpeed': '86.0',
#  'Agility': '91.0',
#  'Balance': '95.0',
#  'BallControl': '96.0',
#  'Composure': '96.0',
#  'Dribbling': '97.0',
#  'Reactions': '95.0',
#  'Skill Moves': '4.0',
#  'Work Rate': 'Medium/ Medium',
#  'Body Type': 'Messi',
#  'Position': 'RF',
#  'ShotPower': '85.0',
#  'Jumping': '68.0',
#  'LongShots': '94.0',
#  'Penalties': '75.0',
#  'Jersey Number': '10.0'}

# %% [raw]
# 到目前為止， 我們的成果
#
# # header, lines -> fifa
#
# # list of dict(s), each dict representing an athelete
#
# -----
# 我們用到（已經學過）的技巧和知識
#
# - csv handling
#
# - iterable
#
# - list comprehension
#
# - for ... with zip()  *
#
# - function <-- reusable tools
#
# - exception handeling

# %% [markdown]
# ## our toolbox

# %%
from collections import Counter 

# 一個欄位有多少相異值

def find_unique_values(key, data):
    return list(set([ath[key] for ath in data]))

# 符合指定條件的運動員有多少個： 國籍是紐西蘭的運動員有幾個？
def find_specific(key, val, data):
    return [ath['Name'] for ath in fifa if ath[key] == val]

# find_specific('Nationality', 'Dominican Republic', fifa)

# 出現個數的排行榜
def find_top_n(key, data, n):
    a = [ath[key] for ath in data]  # item_id_list, count_item_id_list
    return [c[0] for c in Counter(a).most_common()[:n]]

# %%
nationality = find_unique_values('Nationality', fifa)
clubs = find_unique_values('Club', fifa)

# %% [markdown]
# ## Q1: 那個球會的球員平均薪水最高

# %%
def calc_club_wages(c):
    wage_raw = [float(ath['Wage']) for ath in fifa if ath['Club'] == c]
    wage_avg = sum(wage_raw)/len(wage_raw)
    return (wage_avg, c)

wage_list = [calc_club_wages(c) for c in clubs]
sorted(wage_list, reverse=True)[:10]
# Out:
# [(152.03030303030303, 'Real Madrid'),
#  (146.57575757575756, 'FC Barcelona'),
#  (131.68, 'Juventus'),
#  (113.36363636363636, 'Manchester City'),
#  (102.75757575757575, 'Manchester United'),
#  (98.45454545454545, 'Chelsea'),
#  (87.93939393939394, 'Liverpool'),
#  (79.48484848484848, 'Tottenham Hotspur'),
#  (78.82758620689656, 'FC Bayern München'),
#  (78.42424242424242, 'Arsenal')]

# %% [markdown]
# ## Q2 那個國家（地區）球員的平均薪水最高

# %%
def calc_nation_wages(n):
    wage_raw = [ float(ath['Wage']) for ath in fifa if ath['Nationality'] == n]
    wage_avg = sum(wage_raw)/len(wage_raw)
    return (wage_avg, n)

top_n = find_top_n('Nationality', fifa, 30)

wage_list = [
    calc_nation_wages(nation)
    for nation in nationality
    if nation in top_n
]

sorted(wage_list, reverse=True)[:10]
# Out:
# [(18.48076923076923, 'Belgium'),
#  (17.778718258766627, 'Brazil'),
#  (17.006711409395972, 'Uruguay'),
#  (16.32276119402985, 'Spain'),
#  (14.361538461538462, 'Senegal'),
#  (14.31055900621118, 'Portugal'),
#  (14.053610503282275, 'France'),
#  (13.478632478632479, 'Italy'),
#  (11.502668089647813, 'Argentina'),
#  (10.442244224422442, 'Turkey')]

# %% [markdown]
# ## Q3 球衣背號與薪水

# %%
float('')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/tk/rv89xp1n5_q9z8f1qtmvhgsc0000gn/T/ipykernel_17201/1427480730.py in <module>
# ----> 1 float('')
#
# ValueError: could not convert string to float: ''

# %%
def num_conv(s):
    try:
        return int(float(s))
    except ValueError:
        return 0  # Null , NaN 
    
jersey_list = [
    (float(ath['Wage']), ath['Name'])
     for ath in fifa
    # filter rule <- jersey number
    if num_conv(ath['Jersey Number']) == 7
]

sorted(jersey_list, reverse=True)[:5]
# Out:
# [(405.0, 'Cristiano Ronaldo'),
#  (355.0, 'K. De Bruyne'),
#  (340.0, 'Coutinho'),
#  (215.0, 'A. Sánchez'),
#  (145.0, 'H. Mkhitaryan')]

# %% [markdown]
# # Pandas Way

# %%
import pandas as pd

fifa_source = './data/lite_fifa19.csv'

df = pd.read_csv(fifa_source)

df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club  Value   Wage Height  Weight  ...  Skill Moves  \
# 0         FC Barcelona  110.5  565.0    5'7  159lbs  ...          4.0
# 1             Juventus   77.0  405.0    6'2  183lbs  ...          5.0
# 2  Paris Saint-Germain  118.5  290.0    5'9  150lbs  ...          5.0
# 3    Manchester United   72.0  260.0    6'4  168lbs  ...          1.0
# 4      Manchester City  102.0  355.0   5'11  154lbs  ...          4.0
#
#         Work Rate   Body Type  Position  ShotPower  Jumping  LongShots  \
# 0  Medium/ Medium       Messi        RF       85.0     68.0       94.0
# 1       High/ Low  C. Ronaldo        ST       95.0     95.0       93.0
# 2    High/ Medium      Neymar        LW       80.0     61.0       82.0
# 3  Medium/ Medium        Lean        GK       31.0     67.0       12.0
# 4      High/ High      Normal       RCM       91.0     63.0       91.0
#
#    Dribbling.1  Penalties  Jersey Number
# 0         97.0       75.0           10.0
# 1         88.0       85.0            7.0
# 2         96.0       81.0           10.0
# 3         18.0       40.0            1.0
# 4         86.0       79.0            7.0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 資料集基本資料

# %%
df.shape
# Out:
# (18207, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            18207 non-null  object
#  1   Age             18207 non-null  int64
#  2   Nationality     18207 non-null  object
#  3   Overall         18207 non-null  int64
#  4   Potential       18207 non-null  int64
#  5   Club            17966 non-null  object
#  6   Value           18207 non-null  float64
#  7   Wage            18207 non-null  float64
#  8   Height          18159 non-null  object
#  9   Weight          18159 non-null  object
#  10  Special         18207 non-null  int64
#  11  Preferred Foot  18159 non-null  object
#  12  Weak Foot       18159 non-null  float64
#  13  Acceleration    18159 non-null  float64
#  14  SprintSpeed     18159 non-null  float64
#  15  Agility         18159 non-null  float64
#  16  Balance         18159 non-null  float64
#  17  BallControl     18159 non-null  float64
#  18  Composure       18159 non-null  float64
#  19  Dribbling       18159 non-null  float64
#  20  Reactions       18159 non-null  float64
#  21  Skill Moves     18159 non-null  float64
#  22  Work Rate       18159 non-null  object
#  23  Body Type       18159 non-null  object
#  24  Position        18147 non-null  object
#  25  ShotPower       18159 non-null  float64
#  26  Jumping         18159 non-null  float64
#  27  LongShots       18159 non-null  float64
#  28  Dribbling.1     18159 non-null  float64
#  29  Penalties       18159 non-null  float64
#  30  Jersey Number   18147 non-null  float64
# dtypes: float64(18), int64(4), object(9)
# memory usage: 4.3+ MB

# %%
df.describe()
# Out:
#                 Age       Overall  ...     Penalties  Jersey Number
# count  18207.000000  18207.000000  ...  18159.000000   18147.000000
# mean      25.122206     66.238699  ...     48.548598      19.546096
# std        4.669943      6.908930  ...     15.704053      15.947765
# min       16.000000     46.000000  ...      5.000000       1.000000
# 25%       21.000000     62.000000  ...     39.000000       8.000000
# 50%       25.000000     66.000000  ...     49.000000      17.000000
# 75%       28.000000     71.000000  ...     60.000000      26.000000
# max       45.000000     94.000000  ...     92.000000      99.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# ### 缺失值？

# %%
df.isnull().any()

# %%
# df['Jersey Number'].isnull()
df[df['Jersey Number'].isnull()][['Name', 'Club', 'Nationality', 'Wage', 'Jersey Number']]
# Out:
#                   Name                           Club       Nationality  Wage  \
# 5018         R. Raldes                            NaN           Bolivia   0.0
# 6736           J. Arce                            NaN           Bolivia   0.0
# 7922      L. Gutiérrez                            NaN           Bolivia   0.0
# 9905         R. Vargas                            NaN           Bolivia   0.0
# 10628      D. Bejarano                            NaN           Bolivia   0.0
# 13236       J. McNulty                       Rochdale          Scotland   1.0
# 13237       J. Barrera                Boyacá Chicó FC         Nicaragua   1.0
# 13238         J. Stead                   Notts County           England   3.0
# 13239      A. Semprini                        Brescia             Italy   1.0
# 13240       R. Bingham         Hamilton Academical FC           England   1.0
# 13241     K. Dankowski                  Śląsk Wrocław            Poland   1.0
# 13242        I. Colman         Club Atlético Aldosivi         Argentina   2.0
# 13243        M. Feeney                        Everton           England   5.0
# 13244         R. Minor                       Hobro IK           Denmark   2.0
# 13245           Klauss                   HJK Helsinki            Brazil   1.0
# 13246       I. Sissoko                     AS Béziers            France   2.0
# 13247          F. Hart                 SV Mattersburg           Austria   3.0
# 13248    L. McCullough                Tranmere Rovers  Northern Ireland   2.0
# 13249        Li Yunqiu  Shanghai Greenland Shenhua FC          China PR   3.0
# 13250        F. Garcia               Itagüí Leones FC          Paraguay   1.0
# 13251     R. Haemhouts                      NAC Breda           Belgium   2.0
# 13252        E. Binaku                       Malmö FF           Albania   1.0
# 13253        G. Miller                Carlisle United          Scotland   2.0
# 13254       A. Aidonis                  VfB Stuttgart           Germany   2.0
# 13255         L. Sowah         Hamilton Academical FC           Germany   1.0
# 13256        R. Deacon                      Dundee FC           England   1.0
# 13257    Jang Hyun Soo        Suwon Samsung Bluewings    Korea Republic   2.0
# 13258      A. Al Malki                       Al Wehda      Saudi Arabia   3.0
# 13259      E. Guerrero                   CD Palestino             Chile   1.0
# 13260          Hernáiz                    Albacete BP             Spain   1.0
# 13261    H. Al Mansour                       Al Nassr      Saudi Arabia   5.0
# 13262          H. Paul               TSV 1860 München           Germany   1.0
# 13263         S. Bauer       FC Admira Wacker Mödling           Austria   2.0
# 13264       M. Chergui               Grenoble Foot 38            France   1.0
# 13265       D. Gardner                Oldham Athletic           England   3.0
# 13266     L. Bengtsson                    Hammarby IF            Sweden   1.0
# 13267     F. Jaramillo               Itagüí Leones FC          Colombia   1.0
# 13268       L. Garguła                  Miedź Legnica            Poland   1.0
# 13269        S. Rivera            Jaguares de Córdoba          Colombia   1.0
# 13270         Vinicius                        Bologna            Brazil   1.0
# 13271     F. Sepúlveda                 CD Antofagasta             Chile   1.0
# 13272        L. Spence                      Dundee FC          Scotland   1.0
# 13273       B. Lepistu                Kristiansund BK           Estonia   1.0
# 13274      A. Abruscia               TSV 1860 München             Italy   2.0
# 13275      E. González                Boyacá Chicó FC         Venezuela   1.0
# 13276       M. Al Amri                        Al Raed      Saudi Arabia   3.0
# 13277     J. Rebolledo               Deportes Iquique             Chile   1.0
# 13278       C. Mamengi                     FC Utrecht       Netherlands   1.0
# 13279     P. Mazzocchi                        Perugia             Italy   1.0
# 13280        Y. Ammour                Montpellier HSC            France   2.0
# 13281   Jwa Joon Hyeop                   Gyeongnam FC    Korea Republic   1.0
# 13282       O. Marrufo    Tiburones Rojos de Veracruz            Mexico   2.0
# 13283      Han Pengfei            Guizhou Hengfeng FC          China PR   2.0
# 16450          S. Paul                            NaN             India   0.0
# 16539  L. Lalruatthara                            NaN             India   0.0
# 16793       E. Lyngdoh                            NaN             India   0.0
# 17129         J. Singh                            NaN             India   0.0
# 17339         S. Passi                            NaN             India   0.0
# 17436   D. Lalhlimpuia                            NaN             India   0.0
# 17539         C. Singh                            NaN             India   0.0
#
#        Jersey Number
# 5018             NaN
# 6736             NaN
# 7922             NaN
# 9905             NaN
# 10628            NaN
# 13236            NaN
# 13237            NaN
# 13238            NaN
# 13239            NaN
# 13240            NaN
# 13241            NaN
# 13242            NaN
# 13243            NaN
# 13244            NaN
# 13245            NaN
# 13246            NaN
# 13247            NaN
# 13248            NaN
# 13249            NaN
# 13250            NaN
# 13251            NaN
# 13252            NaN
# 13253            NaN
# 13254            NaN
# 13255            NaN
# 13256            NaN
# 13257            NaN
# 13258            NaN
# 13259            NaN
# 13260            NaN
# 13261            NaN
# 13262            NaN
# 13263            NaN
# 13264            NaN
# 13265            NaN
# 13266            NaN
# 13267            NaN
# 13268            NaN
# 13269            NaN
# 13270            NaN
# 13271            NaN
# 13272            NaN
# 13273            NaN
# 13274            NaN
# 13275            NaN
# 13276            NaN
# 13277            NaN
# 13278            NaN
# 13279            NaN
# 13280            NaN
# 13281            NaN
# 13282            NaN
# 13283            NaN
# 16450            NaN
# 16539            NaN
# 16793            NaN
# 17129            NaN
# 17339            NaN
# 17436            NaN
# 17539            NaN

# %% [markdown]
# ## 哪個球會最有錢？球員平均薪水最高

# %%
df.pivot_table(index='Club', aggfunc='mean')

# %%
df.pivot_table(index='Club', aggfunc='mean')['Wage'].sort_values(ascending=False)

# %%
df.groupby(['Club'])['Wage']

# %%
df.groupby(['Club'])['Wage'].agg('mean').to_frame().sort_values(by='Wage', ascending=False)

# %% [markdown]
# ## 穿10號球衣的球員，誰的薪水最高
